# %%
from ultralytics import YOLO

# 1. Load the model (YOLOv12-X-seg for maximum accuracy)
model = YOLO('models/yolo/yolo11s-seg.pt')

# 2. Start Training
results = model.train(
    data='configs/driveindia_yolo11.yaml',
    epochs=10,
    imgsz=1024,          # High res for small object detection
    batch=8,            # Adjust based on GPU VRAM (e.g., 24GB+)
    augment=True,        # Enable Mosaic, MixUp, and Copy-Paste
    overlap_mask=True,   # Critical for dense traffic where objects overlap
    project='DriveIndia_Seg',
    name='v11s_vru_focus'
)
# Out:
# Ultralytics 8.3.235  Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA RTX A3000 Laptop GPU, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=configs/driveindia_yolo11.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=models/yolo/yolo11s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=v11s_vru_focus3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=DriveIndia_Seg, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1477000  ultralytics.nn.modules.head.Segment          [8, 32, 128, [128, 256, 512]]
# YOLO11s-seg summary: 203 layers, 10,085,384 parameters, 10,085,368 gradients, 33.1 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# WARNING AMP: checks skipped. Offline and unable to download YOLO11n for AMP checks. Setting 'amp=True'. If you experience zero-mAP or NaN losses you can disable AMP with amp=False.
# train: Fast image access  (ping: 0.50.0 ms, read: 68.570.2 MB/s, size: 548.0 KB)
# train: Scanning C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\data\final_dataset\labels\train.cache... 1086 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1086/1086 323.9Kit/s 0.0s
# train: C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\data\final_dataset\images\train\F_2_1_1066.jpg: 1 duplicate labels removed
# train: C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\data\final_dataset\images\train\F_2_2_767.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.30.2 ms, read: 254.7151.9 MB/s, size: 501.2 KB)
# val: Scanning C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\data\final_dataset\labels\val.cache... 271 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 271/271 20.8Kit/s 0.0s
# Plotting labels to C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3\labels.jpg...
# WARNING 'RcParams' object has no attribute '_get'
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      6.17G     0.7858      1.986      1.888     0.9814         74       1024: 100% ━━━━━━━━━━━━ 136/136 4.2s/it 9:255.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.6s/it 44.9s1.7ss
#                    all        271       2422      0.788      0.503      0.566      0.444      0.777      0.495      0.546      0.412
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      6.19G     0.7989      1.973      1.117     0.9791         45       1024: 100% ━━━━━━━━━━━━ 136/136 7.6s/it 17:127.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 1.9s/it 32.7s1.9ss
#                    all        271       2422      0.724      0.527      0.532      0.411      0.714      0.514      0.513      0.363
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      6.24G     0.8179      1.905       1.02     0.9977         39       1024: 100% ━━━━━━━━━━━━ 136/136 5.6s/it 12:465.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.0s/it 34.3s1.8ss
#                    all        271       2422      0.819      0.545      0.605      0.472      0.807      0.532      0.578      0.421
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      6.21G     0.7904      1.926     0.9428     0.9847         64       1024: 100% ━━━━━━━━━━━━ 136/136 5.0s/it 11:264.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.3it/s 7.5s0.5s
#                    all        271       2422      0.821      0.538        0.6      0.485      0.808      0.525      0.577      0.426
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      6.19G     0.7559      1.803     0.8706     0.9669         53       1024: 100% ━━━━━━━━━━━━ 136/136 3.8s/it 8:363.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 1.6it/s 10.9s0.5s
#                    all        271       2422      0.817      0.563      0.623      0.501      0.805      0.547      0.597      0.453
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      6.27G     0.7296       1.75     0.8074     0.9537         47       1024: 100% ━━━━━━━━━━━━ 136/136 5.4s/it 12:104.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.4it/s 7.1s0.5s
#                    all        271       2422      0.671      0.541      0.645      0.542      0.655      0.532       0.62      0.496
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      6.18G     0.6846      1.676     0.7484     0.9311         67       1024: 100% ━━━━━━━━━━━━ 136/136 3.5s/it 7:532.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.3it/s 7.4s0.5s
#                    all        271       2422      0.886       0.58      0.661      0.554      0.869      0.566      0.634      0.495
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      6.28G     0.6593      1.635     0.7107     0.9223         50       1024: 100% ━━━━━━━━━━━━ 136/136 5.0s/it 11:235.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.3it/s 7.4s0.4s
#                    all        271       2422       0.67       0.59      0.665      0.567       0.67      0.559      0.634      0.505
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      6.21G     0.6242      1.531     0.6696     0.9096         43       1024: 100% ━━━━━━━━━━━━ 136/136 3.9s/it 8:464.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.2it/s 7.7s0.5s
#                    all        271       2422      0.882       0.58      0.671      0.578      0.883      0.556      0.642      0.515
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      6.22G     0.6001      1.474     0.6388     0.8962         49       1024: 100% ━━━━━━━━━━━━ 136/136 4.2s/it 9:264.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 1.8it/s 9.5s0.7s
#                    all        271       2422      0.906      0.581      0.679      0.588      0.899       0.56      0.652      0.525
#
# 10 epochs completed in 1.886 hours.
# Optimizer stripped from C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3\weights\last.pt, 20.5MB
# Optimizer stripped from C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3\weights\best.pt, 20.5MB
#
# Validating C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3\weights\best.pt...
# Ultralytics 8.3.235  Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA RTX A3000 Laptop GPU, 6144MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,069,912 parameters, 0 gradients, 32.8 GFLOPs
# WARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 6% ╸─────────── 1/17 2.4s/it 0.7s<37.9sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 12% ━─────────── 2/17 1.3s/it 1.3s<19.0sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 18% ━━────────── 3/17 1.0s/it 2.0s<14.2sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 24% ━━╸───────── 4/17 1.1it/s 2.7s<11.6sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 29% ━━━╸──────── 5/17 1.5it/s 3.1s<8.0sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 35% ━━━━──────── 6/17 1.7it/s 3.6s<6.3sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 41% ━━━━╸─────── 7/17 1.8it/s 4.1s<5.6sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 47% ━━━━━╸────── 8/17 1.7it/s 4.8s<5.3sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 53% ━━━━━━────── 9/17 1.7it/s 5.4s<4.8sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 59% ━━━━━━━───── 10/17 1.6it/s 6.1s<4.4sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 65% ━━━━━━━╸──── 11/17 1.5it/s 6.8s<3.9sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 71% ━━━━━━━━──── 12/17 1.5it/s 7.5s<3.3sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 76% ━━━━━━━━━─── 13/17 1.5it/s 8.2s<2.7sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 82% ━━━━━━━━━╸── 14/17 1.5it/s 8.9s<2.0sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 88% ━━━━━━━━━━╸─ 15/17 1.5it/s 9.6s<1.4sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 94% ━━━━━━━━━━━─ 16/17 1.5it/s 10.3s<0.7sWARNING Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 1.6it/s 10.9s
#                    all        271       2422      0.907      0.581      0.679      0.587      0.901      0.559      0.652      0.525
#                    car        256       1085      0.859      0.817      0.892      0.796      0.854      0.789      0.863      0.702
#             motorcycle        175        635      0.864      0.784      0.865       0.67       0.89      0.778      0.867      0.643
#                    bus         93        146      0.908      0.605      0.765      0.684      0.873      0.562      0.706      0.603
#                  train          2          2          1          0          0          0          1          0          0          0
#                  truck        214        554      0.902        0.7      0.871      0.786      0.887      0.664      0.824      0.678
# Speed: 0.6ms preprocess, 22.6ms inference, 0.0ms loss, 4.8ms postprocess per image
# Results saved to C:\Users\RLW1KOR\OneDrive - Bosch Group\AppliedAI\Perception_stack\driveindia-det2seg_image\DriveIndia_Seg\v11s_vru_focus3
